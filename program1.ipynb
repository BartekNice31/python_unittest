# %%
import time
import datetime
import unittest

# %%
a=100.4
assert type(a)==int
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 a=100.4
# ----> 2 assert type(a)==int
#
# AssertionError:

# %%
temperature_1='20.53'
try:
    assert type(temperature_1)==float
except AssertionError:
    print(f"type of temperature must be type of float,not {type(temperature_1)}")
# Out:
# type of temperature must be type of float,not <class 'str'>
