# %%
import time
import datetime
import unittest

# %% [markdown]
# podział testów:
# 1. klasy,komponenty,podsystemy,systemy
# 2. black-box testing, white-box testing
# 3. metoda weryfikacji: sttyczne,dynamiczne
# 4. ze względu na wymagania- funkcjonalne, niefunkcjonalne

# %% [markdown]
# poziomy testowania:
# 0. testowanie jednostkowe
# 1. testowanie integracyjne
# 2. testowanie systemowe
# 3. testowanie akceptacyjne
